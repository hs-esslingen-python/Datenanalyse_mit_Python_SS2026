# %% [markdown]
# # My First Jupyter Lab Notebook
#
# # 2026-03-15 ug

# %%
print("Hello World!!")

# %% [markdown]
# # Wie bekomme ich Hilfe?

# %%
help(print)

# %% [markdown]
# ## Variablen und `print`

# %%
a=7

# %%
print(a)

# %%
a

# %%
a=9

# %%
a=10
a

# %%
c=8

# %% [markdown]
# ## Version von Python ausgeben
# Ausführen eines Befehl wie in einer _Eingabeaufforderung_

# %%
# !python -V

# %% [markdown]
# ## Check Installed Packages
#
# 2026-03-15 ug

# %% [markdown]
# #### Folgende Pakete sollten nach dem Einrichten der virtuelle Umgebung vorhanden sein:
#
# Hinweis: Kann beim ersten Durchlauf länger dauern

# %% [markdown]
# ### numpy -> '2.4.3'

# %%
import numpy
numpy.__version__

# %% [markdown]
# ### matplotlib -> '3.10.8'

# %%
import matplotlib
matplotlib.__version__

# %% [markdown]
# ### scipy -> '1.17.1'

# %%
import scipy
scipy.__version__

# %% [markdown]
# ### pandas -> '3.0.1'

# %%
import pandas
pandas.__version__

# %% [markdown]
# ### seaborn -> '0.13.2'

# %%
import seaborn
seaborn.__version__

# %% [markdown]
# ### sklearn -> '1.8.0'

# %%
import sklearn
sklearn.__version__

# %% [markdown]
# ### statsmodels -> '0.14.6'

# %%
import statsmodels
statsmodels.__version__

# %% [markdown]
# ### hvplot -> '0.12.2'

# %%
import hvplot
hvplot.__version__

# %% [markdown]
# ### openpyxl - '3.1.5'

# %%
import openpyxl
openpyxl.__version__

# %% [markdown]
# ### sqlalchemy -> '2.0.48

# %%
import sqlalchemy
sqlalchemy.__version__

# %% [markdown]
# ### scikit-image -> '0.26.0'

# %%
import skimage
skimage.__version__

# %% [markdown]
# ### opencv -> '4.13.0'

# %%
import cv2
cv2.__version__

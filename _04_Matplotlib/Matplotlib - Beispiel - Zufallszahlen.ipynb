# %% [markdown]
# # Matplotlib - Beispiel - Zufallszahlen
#
# 2026-05-06 - ug - Version 1.4
#
# <!--
#
# In einem Jupyter Notebook unter Visual Studio Code oder in einem Python Skript muss zum Darstellen des Plots der folgende Befehl ausgeführt werden, ansonsten wird der Plot nicht angezeigt:
#
# ``` Python
#
# plt.show()
#
# ```
#
# -->

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Beispiel - Zwei Würfel
#
# Es wird mit zwei Würfeln gleichzeitig gewürfelt und die Augenzahl addiert.
#
# Erstellen eines Histograms mit der Funktion [plt.hist()](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist.html)

# %%
N = 10000
wuerfel1 = np.random.randint(1,7,size=N)
wuerfel2 = np.random.randint(1,7,size=N)

wuerfel_summe = wuerfel1+wuerfel2

plt.hist(wuerfel_summe,bins=np.arange(1.5,13.5,1))
# Out:
# (array([ 278.,  578.,  790., 1082., 1362., 1693., 1445., 1120.,  847.,
#          550.,  255.]),
#  array([ 1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5, 11.5,
#         12.5]),
#  <BarContainer object of 11 artists>)

# %% [markdown]
# ## Beispiel Normalverteilung
#
# Mittelwert $\mu=0$ und Standardabweichung $\sigma=1$

# %%
N = 10000
x = np.random.randn(N)
x.mean(), x.std()
# Out:
# (np.float64(0.014000153936363094), np.float64(0.9921917869229173))

# %% [markdown]
# #### Erstellen eines Histogramms:
#
# [`hist()`](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist.html) - Berechnen und Zeichen eines Histogramms

# %%
plt.hist(x,bins=100)
# Out:
# (array([  1.,   0.,   0.,   0.,   1.,   0.,   2.,   3.,   3.,   3.,   3.,
#           3.,   5.,   7.,   9.,   7.,  12.,  20.,  18.,  17.,  30.,  27.,
#          36.,  33.,  62.,  56.,  62.,  70.,  66.,  79., 100., 110., 118.,
#         152., 157., 149., 178., 226., 238., 210., 243., 287., 287., 273.,
#         301., 299., 327., 310., 319., 316., 335., 316., 287., 284., 284.,
#         279., 256., 249., 260., 209., 217., 190., 165., 178., 153., 160.,
#         132., 106., 102.,  94.,  78.,  65.,  58.,  56.,  34.,  34.,  37.,
#          25.,  22.,  19.,  13.,  20.,  10.,   4.,   4.,   8.,   3.,   4.,
#           3.,   0.,   4.,   0.,   2.,   0.,   3.,   0.,   0.,   1.,   0.,
#           2.]),
#  array([-3.83062346, -3.75267356, -3.67472366, -3.59677376, -3.51882385,
#         -3.44087395, -3.36292405, -3.28497415, -3.20702425, -3.12907435,
#         -3.05112445, -2.97317455, -2.89522465, -2.81727475, -2.73932485,
#         -2.66137495, -2.58342505, -2.50547515, -2.42752524, -2.34957534,
#         -2.27162544, -2.19367554, -2.11572564, -2.03777574, -1.95982584,
#         -1.88187594, -1.80392604, -1.72597614, -1.64802624, -1.57007634,
#         -1.49212644, -1.41417654, -1.33622663, -1.25827673, -1.18032683,
#         -1.10237693, -1.02442703, -0.94647713, -0.86852723, -0.79057733,
#         -0.71262743, -0.63467753, -0.55672763, -0.47877773, -0.40082783,
#         -0.32287793, -0.24492803, -0.16697812, -0.08902822, -0.01107832,
#          0.06687158,  0.14482148,  0.22277138,  0.30072128,  0.37867118,
#          0.45662108,  0.53457098,  0.61252088,  0.69047078,  0.76842068,
#          0.84637058,  0.92432049,  1.00227039,  1.08022029,  1.15817019,
#          1.23612009,  1.31406999,  1.39201989,  1.46996979,  1.54791969,
#          1.62586959,  1.70381949,  1.78176939,  1.85971929,  1.93766919,
#          2.01561909,  2.093569  ,  2.1715189 ,  2.2494688 ,  2.3274187 ,
#          2.4053686 ,  2.4833185 ,  2.5612684 ,  2.6392183 ,  2.7171682 ,
#          2.7951181 ,  2.873068  ,  2.9510179 ,  3.0289678 ,  3.1069177 ,
#          3.18486761,  3.26281751,  3.34076741,  3.41871731,  3.49666721,
#          3.57461711,  3.65256701,  3.73051691,  3.80846681,  3.88641671,
#          3.96436661]),
#  <BarContainer object of 100 artists>)

# %% [markdown]
# Normalverteilung mit speziell vorgegeben Werten für Mittelwert und Standardabweichung können mit der Funktion
# [random.normal()](https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html) erzeugt werden, siehe
# [Create an array with a pre determined mean and standard deviation](https://stackoverflow.com/questions/50177594/create-an-array-with-a-pre-determined-mean-and-standard-deviation)

# %%
N = 10000
my_mean = 0.5
my_std = 3
x = np.random.normal(loc=my_mean, scale=my_std, size=1000)
x.mean(), x.std()
# Out:
# (np.float64(0.5646745537528325), np.float64(2.935981085669438))

# %% [markdown]
# alternative Transformation der von `random.randn()` erzeugten Wert:

# %%
x = my_std * np.random.randn(N) + my_mean
x.mean(), x.std()
# Out:
# (np.float64(0.5263346733875862), np.float64(3.015450708002335))

# %% [markdown]
# #### Erstellen eines Boxplots
#
# [`boxplot`](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.boxplot.html)

# %%
plt.boxplot(x,vert=False)
plt.grid(True)

# %% [markdown]
# ## gleichförmige Verteilung zwischen [0, 1).

# %%
N = 100000
x = np.random.rand(N)
x.mean(), x.std()
# Out:
# (np.float64(0.4988480002463366), np.float64(0.2884070695445642))

# %% [markdown]
# #### Erstellen eines Histogramms:

# %%
plt.hist(x,bins=100)
# Out:
# (array([1018.,  995., 1010., 1015.,  977., 1041.,  984., 1013., 1055.,
#         1038.,  960.,  940.,  982., 1002.,  968., 1050., 1025.,  994.,
#          977.,  986.,  995., 1014., 1022., 1017.,  959.,  983.,  953.,
#         1009., 1005., 1019.,  986., 1051.,  978., 1029., 1071., 1032.,
#         1024., 1002.,  992., 1078., 1005., 1013.,  990., 1003., 1007.,
#         1005., 1013.,  972.,  946., 1027., 1023.,  937.,  975.,  997.,

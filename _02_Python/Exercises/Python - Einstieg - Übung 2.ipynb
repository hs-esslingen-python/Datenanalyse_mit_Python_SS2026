# %% [markdown]
# # Python - Einstieg - Übungen 2
#
# 2024-04-02 ug Version 1.0 Entwurf

# %% [markdown]
# ### Aufgabe: Nachkommastellen extrahieren

# %%
Fließkommazahl = 3.1415926536

# %% [markdown]
# Lösung mit `int()`

# %% [markdown]
# Lösung mit `%` (Modulus)
#
# [Realpython-Python Modulo in Practice: How to Use the % Operator](https://realpython.com/python-modulo-operator)

# %% [markdown]
# Lösung mit Zeichenketten (`split()`, `join()`, `float()`)

# %% [markdown]
# Was passiert bei negativen Fließkommazahlen?

# %% [markdown]
# ### Aufgabe: Winkel auf Eindeutigkeitsbereich einschränken

# %%
winkel = 30 + 2*360
winkel

# %% [markdown]
# Bereich 0 bis 360 Grad

# %%
def winkel_reduzieren_0_360(winkel):
    ...

# %%
winkel_reduzieren_0_360(30.25 + 2*360)

# %%
winkel_reduzieren_0_360(30.25 - 2*360)

# %%
winkel_reduzieren_0_360(-30.25 - 2*360)

# %% [markdown]
# -180 bis 180 Grad

# %%
def winkel_reduzieren_plusminus_180(winkel):
    ...
    return winkel

# %%
winkel_reduzieren_plusminus_180(30.5)

# %%
winkel_reduzieren_plusminus_180(-30.5)

# %%
winkel_reduzieren_plusminus_180(30.5+2*360)

# %%
winkel_reduzieren_plusminus_180(30.5-2*360)

# %% [markdown]
# ### Aufgabe: Zeiten umrechnen
#
# Eine Anzahl Sekunden soll in das Format _Stunden:Minuten:Sekunden_ umgewandelt werden.
#
# Referenz:
# + [Stackoverflow - How do I convert seconds to hours, minutes and seconds?](https://stackoverflow.com/questions/775049/how-do-i-convert-seconds-to-hours-minutes-and-seconds)
# + [Delftstack - How to Convert Seconds Into Hours, Minutes, and Seconds in Python](https://www.delftstack.com/howto/python/python-convert-seconds-to-hours-minutes-seconds/)
# + [divmod()](https://docs.python.org/3/library/functions.html#divmod)

# %%
Stunden_original = 5
Minuten_original = 30
Sekunden_original = 34

# %%
Sekunden_total = (Stunden_original*60+Minuten_original)*60 + Sekunden_original
Sekunden_total

# %%
Stunden = 
Stunden

# %%
Minuten = 
Minuten

# %%
Sekunden = 
Sekunden

# %% [markdown]
# #### `divmod` verwenden
#
# [divmod()](https://docs.python.org/3/library/functions.html#divmod)

# %%
m, s = divmod( , )
h, m = divmod( , )

h, m, s

# %% [markdown]
# #### `datetime.timedelta()` verwenden
#
# [`datetime.timedelta()`](https://docs.python.org/3/library/datetime.html#datetime.timedelta)

# %%
import datetime
str(datetime.timedelta(seconds=Sekunden_total))

# %% [markdown]
# #### `.to_timedelta()` aus Pandas verwenden
#
#  [`.to_timedelta()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.to_timedelta.html#pandas.to_timedelta)

# %%
import pandas as pd
timedelta = pd.to_timedelta(Sekunden_total,unit='s')
timedelta

# %% [markdown]
# ### Aufgabe: Lösen einer quadratischen Gleichung
#
# Aufgabe: Schreiben Sie eine Funktion, die die Lösungen einer quadratischen Gleichung berechnet.
#
# Allgemeine Form einer quadratischen Gleichung:
# $
#   ax^2 + bx+ c = 0
# $
#
# mit $ a,b,c \in \mathbb{R}; a \ne 0$
#
# <br>
#
# Signatur der zu entwickelnden Funktion
# ```Python
# def solve_quadratic_formula(a, b, c):
#     ...
# ```
#
# Lösungen $x_{1,2}$:
# <br>
# $
# x_{1,2} = \frac{-b \pm \sqrt{(b^2-4ac)}}{2a}
# $
#
# Testen Sie die Funktion für folgende Fälle:
#
# 1) a = 2, b = -8 und c = 6  (erwartete Lösungen: 1 und 3.)
# 2) a = 2, b = -8 , c = 8 (erwartete Lösingen: 2 und 2)
# 3) a = 2, b = -6, c = 11  (keine reelle Lösung)
#
# ---------
# Referenz:
# + [Wikipedia - Quadratische Gleichung](https://de.wikipedia.org/wiki/Quadratische_Gleichung)
# + [Bodo Schönfeld - Quadratische Gleichungen mit Python berechnen](https://bodo-schoenfeld.de/quadratische-gleichungen-mit-python-berechnen/) -> Vorsicht enthält Fehler
# + [Heise - LaTeX-Mathematische-Symbole-einfuegen](https://www.heise.de/tipps-tricks/LaTeX-Mathematische-Symbole-einfuegen-4996350.html)

# %%
import math
def solve_quadratic_formula(a, b, c):
    ...

# %% [markdown]
# Testen Sie die Funktion für folgende Fälle:
#
# Fall1: a = 2, b = -8 und c = 6  (erwartete Lösungen: 1 und 3.)

# %%
a = 2
b = -8 
c = 6 
result = solve_quadratic_formula(a, b, c)
result

# %%
x1 = result[0]
a*x1**2+b*x1+c

# %%
x2 = result[1]
a*x2**2+b*x2+c

# %% [markdown]
# Fall2: a = 2, b = -8 , c = 8 (erwartete Lösingen: 2 und 2)

# %%
result = solve_quadratic_formula(2, -8, 8)
result

# %% [markdown]
# Fall3: a = 2, b = -6, c = 11  (keine reelle Lösung)

# %%
result = solve_quadratic_formula(2, -6, 11)
result

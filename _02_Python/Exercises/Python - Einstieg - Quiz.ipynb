# %% [markdown]
# # Python - Einstieg - Quiz 3
#
# 2025-04-08 ug Version 1.0 Entwurf
#
# -----
# Referenz:
# + https://programiz.pro/

# %% [markdown]
# **Frage1:** Im folgenden Beispiel wird der Variable `n` ein ... Wert zugewiesen.
# ```Python
# n = '5'
# ```
# Antwort:
# 1. Integer
# 2. Float
# 3. String
# 4. Operator

# %% [markdown]
# **Frage2:** Was ist der Output des folgenden Beispiels?
# ```Python
# a=3.44
# b=3
# result = a+b
# print (type(result))
# ```
# Antwort:
# 1. <class 'int'>
# 1. <class 'string'>
# 1. Value Error
# 1. <class 'float'>

# %% [markdown]
# **Frage3:** Was ist die Ausgabe des folgenden Beispiels?
#
# ```Python
# str1 = 'abc'
# print(str1 * 3)
# ```
#
# Antwort:
# 1. abc
# 2. abcabcabc
# 3. TypeError
# 4. abcdefghi

# %% [markdown]
# **Frage4:** Was ist die korrekte Ausgabe des folgenden Beispiels?
# ```Python
# str1 = '4'
# str2 = '3'
# result = str2+str1
# print(result)
# ```
# Antwort:
# 1. '43'
# 2. 7
# 3. '34'
# 4. Error

# %% [markdown]
# **Frage5**: Welche der folgenden Anweisungen gibt die Zeile `Hello World` auf den Bildschirm aus?
#
# Antworten:
# 1. `print('Hello World')`
# 2. `print("Hello World")`
# 3. `print("Hello" + ' ' + "World")`
# 4. `print("Hello", 'World')`

# %% [markdown]
# **Frage6:** Welches der folgenden Beispiel sind gültige Variablennamen in Python?
#
# Antworten:
# 1. _number
# 2. if_not
# 3. in
# 4. 3Sat

# %% [markdown]
# **Frage7:** Durch welchn Zeichen kann eine Zeichenkette in Python eingeschlossen werden?
#
# Antwort:
# 1. Einfachen Anführungszeichen
# 2. Doppelte Anführungszeichen
# 3. Größer und Kleiner-Zeichen
# 4. Drei einfache Anführungszeichen

# %% [markdown]
# **Frage8:** Was entspricht diesen Ausdruck `2**3`?
#
# Antworten:
# 1. `2 * 3`
# 2. `2003`
# 3. `2 * 2 * 2`
# 4. `2 + 2 + 2`

# %% [markdown]
# **Frage9:** Was ist das Ergebnis des folgenden Ausdrucks?
#
# ```Python
# print((10 - 4) * 2 - 1)
# ```
#
# Antwort:
# 1. 6
# 2. 11
# 3. Error
# 4. 0

# %% [markdown]
# # Python - Einstieg - Übungen 3
#
# 2025-04-08 ug Version 1.1 Entwurf

# %% [markdown]
# ## Übung zu Listen

# %% [markdown]
# Aufgabe1: Erstellen Sie eine Liste _Farben1_, die die Elemente 'rot', 'grün' und 'blau' enthält.
# Nutzen Sie eckige Klammer `[]`

# %%
Farben1 = ['rot', 'grün', 'blau']
Farben1
# Out:
# ['rot', 'grün', 'blau']

# %% [markdown]
# Aufgabe2: Erzeugen Sie eine zweite Liste _Farben2_ mit den Elemente 'gelb', 'cyan', 'magenta' indem Sie zuerst ein Tupel erstellen und dann mit der `list()`-Funktion in eine Liste wandeln.

# %%
Farben2 = list(('gelb', 'cyan', 'magenta'))
Farben2
# Out:
# ['gelb', 'cyan', 'magenta']

# %% [markdown]
# Aufgabe3: Fassen Sie die beiden Listen zusammen in einer Liste _Farben3_ zusammen.

# %%
Farben3 = Farben1+Farben2
Farben3
# Out:
# ['rot', 'grün', 'blau', 'gelb', 'cyan', 'magenta']

# %% [markdown]
# Aufgabe4: Erstellen Sie ein Referenz der Liste und nennen Sie diese _Farben1_Referenz_

# %%
Farben1_Referenz = Farben1
print(f'{id(Farben1_Referenz)=}')
print(f'{id(Farben1)=}')
print(f'{Farben1_Referenz is Farben1=}')
Farben1_Referenz
# Out:
# id(Farben1_Referenz)=2247648743488
# id(Farben1)=2247648743488
# Farben1_Referenz is Farben1=True
# ['rot', 'grün', 'blau']

# %% [markdown]
# Aufgabe5: Erstellen Sie eine Kopie der Liste _Farben1_ und nennen Sie sie _Farben1_Kopie_

# %%
Farben1_Kopie = Farben1.copy()
print(f'{id(Farben1_Kopie)=}')
print(f'{id(Farben1)=}')
print(f'{Farben1_Kopie is Farben1=}')
Farben1_Kopie
# Out:
# id(Farben1_Kopie)=2247648883968
# id(Farben1)=2247648743488
# Farben1_Kopie is Farben1=False
# ['rot', 'grün', 'blau']

# %% [markdown]
# Aufgabe6: Fügen Sie die Elemente der Liste _Farben2_ in die Liste _Farben1_ hinein.

# %%
Farben1.extend(Farben2)
Farben1
# Out:
# ['rot', 'grün', 'blau', 'gelb', 'cyan', 'magenta']

# %% [markdown]
# Aufgabe7: Geben Sie Liste _Farben1_Referenz_ und Liste _Farben1_Kopie_ aus

# %%
Farben1_Referenz
# Out:
# ['rot', 'grün', 'blau', 'gelb', 'cyan', 'magenta']

# %%
Farben1_Kopie
# Out:
# ['rot', 'grün', 'blau']

# %% [markdown]
# Aufgabe8: Hängen Sie das Element 'violett' an das Ende der Liste _Farben3_.

# %%
Farben3.append('violett')
Farben3
# Out:
# ['rot', 'grün', 'blau', 'gelb', 'cyan', 'magenta', 'violett']

# %% [markdown]
# Aufgabe9: Wie viele Element enthält die Liste _Farben3_?

# %%
len(Farben3)

# %% [markdown]
# Machen Sie Beispiele zu den folgenden Methoden
# + `.insert()`- Methode:  einfügen an beliebiger Position
# + `.remove()`- Methode:  entfernen eines Elements aus der Liste anhand des Elementnamens
# + `.pop()` - Methode:    letzten Elements aus einer Liste entfernen und zurückgeben
# + `.reverse()` - Methode: Reihenfolge der Liste umkehren
# + `.sort()` - Methode:   Sortieren der Liste
# + `.index()` - Method:   Index zu einem gegeben Element suchen

# %%
Farben3.insert(2,'pink')
Farben3

# %%
Farben3.remove('blau')

# %%
Farben3.pop()

# %%
Farben3.reverse()
Farben3

# %%
Farben3.sort()
Farben3

# %%
Farben3.index('gelb')

# %% [markdown]
# # weitere Aufgaben
#
# + in Operator
# + .sort() und sorted  (einfache Liste; Liste mit Tupel)
# + min(), max() und sum()
# + Indexing
# + Slicing
# + Teillisten in Listen einfügen
# + Zugriff auf verschachtelte Listen
# + Doppelte Werte aus Liste entfernen
# + Elemente einer Liste mit for Schleife bearbeiten (verwendet enumerate, tuple unpacking, break, continue)

# %%
Liste = ['a','b','c','d','e']
for k,Element in enumerate(Liste, start=1):
    print(f"{k}.Element ist {Element}")

# %% [markdown]
# + while Schleife
# + range()

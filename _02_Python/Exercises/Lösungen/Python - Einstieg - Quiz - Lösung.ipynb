# %% [markdown]
# # Python - Einstieg - Quiz 3
#
# 2026-05-04 ug Version 1.1
#
# -----
# Referenz:
# + https://programiz.pro/

# %% [markdown]
# ----
# **Frage1:** Im folgenden Beispiel wird der Variable `n` ein ... Wert zugewiesen.
# ```Python
# n = '5'
# ```
# Antwort:
# 1. Integer
# 2. Float
# 3. String
# 4. Operator

# %%
n='5'
type(n)

# %% [markdown]
# Lösung: Antwort Nr. 3
# <br>
# Zeichenketten (Strings) stehen in Anführungszeichen

# %% [markdown]
# ----
# **Frage2:** Was ist der Output des folgenden Beispiels?
# ```Python
# a=3.44
# b=3
# result = a+b
# print (type(result))
# ```
# Antwort:
# 1. <class 'int'>
# 1. <class 'string'>
# 1. Value Error
# 1. <class 'float'>

# %%
a=3.44
b=3
result = a+b
print (type(result))

# %% [markdown]
# Lösung: Antwort Nr. 4
# <br>
# Implizite Typumwandlung. Der Wert der Variablen `b` wird automatisch in einen Float-Wert umgewandelt.

# %% [markdown]
# ----
# **Frage3:** Was ist die Ausgabe des folgenden Beispiels?
#
# ```Python
# str1 = 'abc'
# print(str1 * 3)
# ```
#
# Antwort:
# 1. abc
# 2. abcabcabc
# 3. TypeError
# 4. abcdefghi

# %%
str1 = 'abc'
print(str1 * 3)

# %% [markdown]
# Lösung: Antwort Nr. 2
# <br>
# Bei Zeichenketten wiederholt der `*`-Operatier die Zeichenkette sooft welche Zahl dort steht.

# %% [markdown]
# ----
# **Frage4:** Was ist die korrekte Ausgabe des folgenden Beispiels?
# ```Python
# str1 = '4'
# str2 = '3'
# result = str2+str1
# print(result)
# ```
# Antwort:
# 1. '43'
# 2. 7
# 3. '34'
# 4. Error

# %%
str1 = '4'
str2 = '3'
result = str2+str1
print(result)

# %% [markdown]
# Lösung: Antwort Nr. 3
# <br>
# Der `+`-Operator hängt zwei Zeichenketten aneinander.

# %% [markdown]
# ----
# **Frage5**: Welche der folgenden Anweisungen gibt die Zeile `Hello World` auf den Bildschirm aus?
#
# Antworten:
# 1. `print('Hello World')`
# 2. `print("Hello World")`
# 3. `print("Hello" + ' ' + "World")`
# 4. `print("Hello", 'World')`

# %%
print('Hello World')
print("Hello World")
print("Hello" + ' ' + "World")
print("Hello", 'World')

# %% [markdown]
# Lösung: Antwort Nr. 1,2,3 und 4; alle vier Antworten.

# %% [markdown]
# ------
# **Frage6:** Welches der folgenden Beispiel sind gültige Variablennamen in Python?
#
# Antworten:
# 1. _number
# 2. if_not
# 3. in
# 4. 3Sat

# %%
_number = 1

# %%
if_not = 1

# %%
in = 1

# %%
3Sat =

# %% [markdown]
# Lösung: Antwort Nr. 1 und 2
# <br>
# `in` ist ein Python-Schlüsselwort und `3Sat` beginnt mit einer Zahl.

# %% [markdown]
# ----
# **Frage7:** Durch welche Zeichen kann eine Zeichenkette in Python eingeschlossen werden?
#
# Antwort:
# 1. Einfachen Anführungszeichen  `'Zeichenkette'`
# 2. Doppelte Anführungszeichen   `"Zeichenkette"`
# 3. Größer und Kleiner-Zeichen  `<Zeichenkette>`
# 4. Drei einfache Anführungszeichen `"""Zeichenkette"""`

# %%
'Zeichenkette'

# %%
"Zeichenkette"

# %%
<Zeichenkette>

# %%
"""Zeichenkette"""

# %% [markdown]
# Lösung: Antwort Nr. 1,2 und 4

# %% [markdown]
# ----
# **Frage8:** Was entspricht diesen Ausdruck `2**3`?
#
# Antworten:
# 1. `2 * 3`
# 2. `2003`
# 3. `2 * 2 * 2`
# 4. `2 + 2 + 2`

# %% [markdown]
# Lösung: Antwort Nr. 3
# <br>
# Der `**`-Operator ist der Potenz-Operator und berechnet die Potenz des rechten Operand zur Basis des linken Operands.

# %% [markdown]
# ----
# **Frage9:** Was ist das Ergebnis des folgenden Ausdrucks?
#
# ```Python
# print((10 - 4) * 2 - 1)
# ```
#
# Antwort:
# 1. 6
# 2. 11
# 3. Error
# 4. 0

# %%
print((10 - 4) * 2 - 1)

# %% [markdown]
# Lösung: Antwort Nr. 2
# <br>
# Klammern gehen vor Punkt; und Punkt geht vor Strichrechnung.

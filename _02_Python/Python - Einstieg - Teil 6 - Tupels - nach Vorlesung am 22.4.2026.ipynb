# %% [markdown]
# # Python - Einstieg - Teil 6 - Tupel
#
# Datentyp Tupel  - "nicht veränderbare Liste"
#
# Tupels (Tuples engl.) werden verwendet, um mehrere Element in einer einzigen Variablen zu speichern, die später nicht mehr verändert werden muss.
#
# Ein Tupel ist im Vergleich zu einer Liste schneller in der Ausführung und benötigt weniger Speicherplatz.
#
# 2026-04-01 ug Version 1.4
#
# <!---
# Todo:
#
# --->

# %% [markdown]
# -----
# ### Datentyp Tupel  - "nicht veränderbare Liste"
#
# Definition durch runde Klammern `()`

# %%
tupel_3 = (1,2,3)
tupel_3
# Out:
# (1, 2, 3)

# %% [markdown]
# Datentyp `tuple`

# %%
type(tupel_3)
# Out:
# tuple

# %% [markdown]
# Der Zugriff auf ein Element aus einem Tupel erfolgt durch eckige Klammern `[]` und durch Angabe eines Index.
# Der Index beginnt mit der Zahl 0.

# %%
tupel_3[0]
# Out:
# 1

# %%
tupel_3[1]
# Out:
# 2

# %%
tupel_3[2]
# Out:
# 3

# %% [markdown]
# Zugriff auf einen Index der nicht mehr im Tupel liegen würde, erzeugt eine `IndexError` mit der Fehlermeldung "tuple index out of range"

# %%
tupel_3[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 tupel_3[3]
#
# IndexError: tuple index out of range

# %% [markdown]
# Versucht man, ein Element eines Tupels zu ändern, reagiert Python mit einem `TypeError` der Fehlermeldung "'tuple' object does not support item assignment" darauf:

# %%
tupel_3[1] ='neu'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 tupel_3[1] ='neu'
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# #### `tuple()` - Funktion
# Die `tuple()` - Funktion dient zur Erzeugung eines Tupels aus anderen Objekten - hier einer Liste `[1,2,3]`, die wir aber erst später behandeln.

# %%
tupel_3b = tuple([1,2,3])
tupel_3b
# Out:
# (1, 2, 3)

# %% [markdown]
# Im Vergleich dazu wird eine Liste durch eckige Klammern dargestellt:

# %%
[1,2,3]
# Out:
# [1, 2, 3]

# %% [markdown]
# Mit der Funktion `len()` kann die Anzahl der Elemente im Tupel bestimmen:

# %%
len(tupel_3b)
# Out:
# 3

# %% [markdown]
# ## spezielle Tupels

# %% [markdown]
# das leere Tupel

# %%
tupel_0 = ()
tupel_0
# Out:
# ()

# %%
type(tupel_0)
# Out:
# tuple

# %% [markdown]
# ein Tupel mit nur einem Element - das Komma nach dem Element ist wichtig.

# %%
tupel_1 = (1,)
tupel_1
# Out:
# (1,)

# %%
type(tupel_1)
# Out:
# tuple

# %% [markdown]
# Bitte beachten: eine Zahl in Klammern ergibt kein Tupel:

# %%
kein_tupel_object_mit_einem_Element = (1)

# %%
type(kein_tupel_object_mit_einem_Element)
# Out:
# int

# %%
kein_tupel_object_mit_einem_Element
# Out:
# 1

# %% [markdown]
# ---
# #### Definition eines Tupel ohne Klammern

# %%
tupel_object = 10,20,30
tupel_object
# Out:
# (10, 20, 30)

# %%
type(tupel_object)
# Out:
# tuple

# %%
tupel_object[1]
# Out:
# 20

# %% [markdown]
# #### Tupel ohne Klammern mit nur einem Element

# %%
tupel_object_mit_einem_Element = 10,

# %%
type(tupel_object_mit_einem_Element)
# Out:
# tuple

# %%
tupel_object_mit_einem_Element
# Out:
# (10,)

# %% [markdown]
# Vorsicht vor Tippfehlern - Fließkommazahl mit einem Komma `,` geschrieben

# %%
tupel_object_mit_einem_Element = 10,5

# %%
tupel_object_mit_einem_Element
# Out:
# (10, 5)

# %% [markdown]
# ### Tupel von Tupel -> Matrix

# %%
tupel_von_tupel = ((1,2,3),(4,5,6),(7,8,9))
tupel_von_tupel
# Out:
# ((1, 2, 3), (4, 5, 6), (7, 8, 9))

# %% [markdown]
# Zugriff der Reihenfolge nach

# %%
tupel_von_tupel[0]
# Out:
# (1, 2, 3)

# %%
tupel_von_tupel[0][1]
# Out:
# 2

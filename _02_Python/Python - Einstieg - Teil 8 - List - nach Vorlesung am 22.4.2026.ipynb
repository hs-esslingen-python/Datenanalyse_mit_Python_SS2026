# %% [markdown]
# # Python - Einstieg - Teil 8 - List
#
# Themen:
# * Listen - "Aufzählung"
#
# 2026-04-22 ug Version 1.5
#
# <!---
# Todo:
#
# --->

# %% [markdown]
# ------
# ### Listen - "Aufzählung"
#
# Definition mit eckigen Klammern `[]`.

# %%
[1,2,3]
# Out:
# [1, 2, 3]

# %% [markdown]
# Datentyp einer Liste ist `list`.

# %%
Liste = [1,2,3]
type(Liste)
# Out:
# list

# %% [markdown]
# Länge einer Liste bestimmen mit der `len()` Funktion

# %%
len(Liste)
# Out:
# 3

# %% [markdown]
# Prüfen ob ein Wert in einer Liste enthalten ist, erfolgt mit dem `in` Operator und liefert Boolean zurück:

# %%
2 in Liste
# Out:
# True

# %%
4 in Liste
# Out:
# False

# %% [markdown]
# Listen lassen sich beliebig ineinander verschachteln - Listen können wieder Listen enthalten.

# %%
['hi',1,5.7,[1,2,[4,5,6]]]
# Out:
# ['hi', 1, 5.7, [1, 2, [4, 5, 6]]]

# %% [markdown]
# #### Ein Element an das Ende einer Liste anfügen

# %%
my_list = ['a','b','c']

# %% [markdown]
# mit dem `+` Operator:

# %%
['a','b','c'] + ['d']
# Out:
# ['a', 'b', 'c', 'd']

# %%
my_list + ['d']
# Out:
# ['a', 'b', 'c', 'd']

# %%
my_list + ['d','e']
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %% [markdown]
# Bei Verbinden von zwei Listen mit dem `+` Operator wird eine neue Liste erzeugt.
# <br>
# Die Liste `my_list` selber bleibt unverändert.

# %%
my_list
# Out:
# ['a', 'b', 'c']

# %% [markdown]
# Beide Operanden müssen aber Listen sein, sonst gibt es eine `TypeError`-Fehlermeldung:

# %%
my_list + 'd'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 my_list + 'd'
#
# TypeError: can only concatenate list (not "str") to list

# %% [markdown]
# Anhängen eines Elementes mit der `append()`-Methode:

# %%
my_list.append('d')
my_list
# Out:
# ['a', 'b', 'c', 'd']

# %% [markdown]
# Durch den Befehl append() wird ein Element an die Liste angehängt. Die Liste wird verändert.

# %% [markdown]
# Was sind Methoden?
# <br>
# Methoden sind Funktionen, die einem Objekt fest zugeordnet sind und die auf die Daten des Objekts zugreifen können.
# Wir werden Methoden beim Thema Funktionen und Klassen ausführlicher behandeln.

# %% [markdown]
# Zwei Listen zusammenfügen mit der `append()`-Methode funktioniert nicht:

# %%
my_list = ['a','b','c']
my_list2 = ['d','e']
my_list.append(my_list2)
my_list
# Out:
# ['a', 'b', 'c', ['d', 'e']]

# %% [markdown]
# mit `append()` wird eine Liste wird Elememt in eine Liste eingefügt. Dies ist nicht das was wir hier wollen.
#
# mit `extend()` werden die Elemente einer Liste als Elemente in eine Liste eingefügt:

# %%
my_list = ['a','b','c']
my_list2 = ['d','e']
my_list.extend(my_list2)
my_list
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %% [markdown]
# dies entspricht dem Verhalten des `+` Operators:

# %%
my_list = ['a','b','c']
my_list2 = ['d','e']
my_list + my_list2
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %% [markdown]
# Aber es gibt einen Unterschied:
# + a) der `+` Operator erstellt eine neue Liste
# + b) die `extend()` Methode verändert die ursprüngliche Liste

# %% [markdown]
# Weitere Methoden von Listen:
#
# + `.insert()`- Methode:  Element einfügen an beliebiger Position
# + `.remove()`- Methode:  entfernen eines Elements aus der Liste anhand des Elementnamens
# + `.pop()` - Methode:    letzten Elements aus einer Liste entfernen und zurückgeben
# + `.reverse()` - Methode: Reihenfolge der Liste umkehren
# + `.sort()` - Methode:   Sortieren der Liste
# + `.index()` - Method:   Index zu einem gegeben Element suchen

# %% [markdown]
# Beispiel: `.reverse()`-Methode -> Liste wird durch Ausführen der`.reverse()`-Methode verändert:

# %%
my_list = ['a', 'b', 'c', 'd', 'e']
my_list.reverse()
my_list
# Out:
# ['e', 'd', 'c', 'b', 'a']

# %%
my_list.sort()
my_list
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
idx = my_list.index('d')
idx
# Out:
# 3

# %%
my_list[idx]
# Out:
# 'd'

# %% [markdown]
# Liste mit doppelten Einträgen

# %%
my_list2 = ['a', 'd', 'c', 'd', 'e', 'f', 'g' ,'d']
my_list2.index('d')
# Out:
# 1

# %% [markdown]
# Um den zweiten Eintrag 'd'zu bekommen, wird die Index suche ab dem Index 2 gestartet:

# %%
my_list2.index('d',2)
# Out:
# 3

# %% [markdown]
# ### Sortien von Listen - `.sort()`-Methode und `sorted()`-Funktion
# Beispiel: `.sort()`-Methode -> Liste wird durch Ausführen der `.sort()`-Methode verändert:

# %%
my_list = ['c', 'e', 'd',  'b', 'a']
my_list.sort()
my_list
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %% [markdown]
# `sorted()`-Funktion  - gibt eine sortierte Liste zurück; ursprüngliche Liste bleibt unverändert:

# %%
my_list = ['c', 'e', 'd',  'b', 'a']
print('sorted(my_list):',sorted(my_list))
print('my_list        :',my_list)
# Out:
# sorted(my_list): ['a', 'b', 'c', 'd', 'e']
# my_list        : ['c', 'e', 'd', 'b', 'a']

# %%
type(sorted)

# %% [markdown]
# weitere Funktionen, die auf Listen angewendet werden können:
#
# `min()`, `max()`, `sum()` - Funktion
#
# Die `sum()` - Funktion benötigt eine Listen mit Zahlen.

# %%
my_list_int = [1,2,3,5,4]
min(my_list_int), max(my_list_int), sum(my_list_int)
# Out:
# (1, 5, 15)

# %%
my_list_str = ['c', 'e', 'd', 'b', 'a']
min(my_list_str), max(my_list_str)
# Out:
# ('a', 'e')

# %%
sum(my_list_str)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 sum(my_list_str)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# Sortieren einer inhomogenen Liste mit _int_ und _str_ ist nicht möglich, weil der Vergleich nicht definiert ist

# %%
my_list = [1,'c', 'e', 'd',  'b', 'a',3]
my_list.sort()
my_list
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 my_list = [1,'c', 'e', 'd',  'b', 'a',3]
# ----> 2 my_list.sort()
#       3 my_list
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %% [markdown]
# Zahlen als Zeichenkette darstellen
# '1' < 'A' < 'a'

# %%
my_list = ['1','c', 'e', 'd','bcd', 'b', 'a','3','A','B','ABC']
my_list.sort()
my_list
# Out:
# ['1', '3', 'A', 'ABC', 'B', 'a', 'b', 'bcd', 'c', 'd', 'e']

# %% [markdown]
# ### Zugriff auf die Einträge in Listen
#
# Der Zugriff auf Listen erfolgt mit eckigen Klammern `[]`
#
# Beispielliste:
#
#     Liste           [0, 1, 2, 3, 4]

# %%
my_list = [0,1,2,3,4]
my_list
# Out:
# [0, 1, 2, 3, 4]

# %% [markdown]
# #### Zugriff auf ein Element in der Liste - **Indizieren**
#
# `my_list[index]`
#
#     Liste           [0, 1, 2, 3, 4]
#     Index vorwärts   0  1  2  3  4
#     Index rückwärts -5 -4 -3 -2 -1

# %%
my_list[0]
# Out:
# 0

# %%
my_list[1]
# Out:
# 1

# %% [markdown]
# negativer Index -> Zugriff vom Ende der Liste gezählt

# %%
my_list[-1]
# Out:
# 4

# %%
my_list[-2]
# Out:
# 3

# %% [markdown]
# Zugriff auf ein Element außerhalb des zulässigen Index-Bereiches fürt zu einer `IndexError`-Fehlermeldung:

# %%
my_list[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 my_list[5]
#
# IndexError: list index out of range

# %% [markdown]
# Verwenden einer Variable als Index

# %%
idx = -1
my_list[idx]
# Out:
# 4

# %% [markdown]
# Index muss aber eine Ganzzahl, also vom Typ _int_, sein, sonst gibt es eine `TypeError`-Fehlermeldung:

# %%
idx = -1.5
my_list[idx]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 2
#       1 idx = -1.5
# ----> 2 my_list[idx]
#
# TypeError: list indices must be integers or slices, not float

# %% [markdown]
# Float-Zahl mit `int()` in eine Ganzzahl wandeln.

# %%
idx = -1.5
print(int(idx))
my_list[int(idx)]
# Out:
# -1
# 4

# %% [markdown]
# Zugriff mit einer Zeichenkette als Index, liefert eine `TypeError`-Fehlermeldung:

# %%
s = '1'
my_list[s]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 2
#       1 s = '1'
# ----> 2 my_list[s]
#
# TypeError: list indices must be integers or slices, not str

# %%
s = '1'
my_list[int(s)]
# Out:
# 1

# %% [markdown]
# Fehlermeldungen:
#
# - Index Fehler `IndexError:` -> Index außerhalb des zulässigen Bereichs
# - Type Fehler `TypeError:` -> Index ist nicht vom Typ Integer

# %% [markdown]
# #### Zugriff auf eine Teil-Liste - **Slicing**
#
# `my_list[Start_Index:End_Index:Schrittweite]`
#
# Rückgabe als Liste, anfangen bei 'Start_Index' bis **eins** vor 'End_Index' (nicht mehr enthalten)
#
# ```
#     Liste           [0, 1, 2, 3, 4]
#     Index vorwärts   0  1  2  3  4  5
#     Index rückwärts -5 -4 -3 -2 -1
# ```
#
# Die Default-Schrittweite ist 1. Die Schrittweite kann positive und negative Ganzzahlen annehmen

# %%
my_list = [0,1,2,3,4]

# %% [markdown]
# Ausgabe der ersten drei Werte der Liste:

# %%
my_list[0:3]
# Out:
# [0, 1, 2]

# %%
my_list[0:3:1]
# Out:
# [0, 1, 2]

# %%
my_list[0:3:2]
# Out:
# [0, 2]

# %% [markdown]
# Die Null am Anfang kann weggelassen werden:

# %%
my_list[:3]
# Out:
# [0, 1, 2]

# %% [markdown]
# Ausgabe ab dem zweiten Element bis zum Schluss der Liste:

# %%
my_list[1:]
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# alternativ:

# %%
my_list[1:5]
# Out:
# [1, 2, 3, 4]

# %%
my_list[1:-1]
# Out:
# [1, 2, 3]

# %% [markdown]
# Ausgabe der letzten beiden Elemente der Liste:

# %%
my_list[-2:]
# Out:
# [3, 4]

# %%
my_list[-2:0]
# Out:
# []

# %%
my_list[-2:0:-1]
# Out:
# [3, 2, 1]

# %%
my_list[-2::-1]
# Out:
# [3, 2, 1, 0]

# %% [markdown]
# Ausgabe jedes zweiten Elements der Liste
# - Schrittweite wird auf 2 gesetzt und
# - Start und Stop-Werte lasse ich weg (sucht sich Python selber)
#
# ```
#     Liste           [0, 1, 2, 3, 4]
#     Index vorwärts   0  1  2  3  4  5
#     Index rückwärts -5 -4 -3 -2 -1
# ```

# %%
my_list[0:5:2]
# Out:
# [0, 2, 4]

# %%
my_list[::2]
# Out:
# [0, 2, 4]

# %% [markdown]
# Beispiel: Start bei Index=1 und Stop bei Index -2 (nicht mehr enthalten):
# ```
#     Liste           [0, 1, 2, 3, 4]
#     Index vorwärts   0  1  2  3  4  5
#     Index rückwärts -5 -4 -3 -2 -1
# ```

# %%
my_list[1:-2:2]
# Out:
# [1]

# %% [markdown]
# Beispiele mit negative Schrittweite
# ```
#     Liste           [0, 1, 2, 3, 4]
#     Index vorwärts   0  1  2  3  4  5
#     Index rückwärts -5 -4 -3 -2 -1
# ```
#
# Start bei Index=1 und Stop bei Index 4 (nicht mehr enthalten), aber eine negativen Schrittweite -1, liefert eine leere Liste, weil Start zu Stop nicht zur Schrittweite passt

# %%
my_list[1:4:-1]
# Out:
# []

# %% [markdown]
# Vertauschen von Start nach Stop liefert jetzt eine gefüllte Liste zurück:

# %%
my_list[4:1:-1]
# Out:
# [4, 3, 2]

# %% [markdown]
# Liste umkehren -> Schrittweite auf -1

# %%
my_list[::-1]
# Out:
# [4, 3, 2, 1, 0]

# %%
my_list
# Out:
# [0, 1, 2, 3, 4]

# %% [markdown]
# Die Anweisung `my_list[::-1]` verändert die Liste selber nicht.

# %% [markdown]
# Alternative Lösung mit `.reverse()`:
# <br>
# Die `.reverse()`-Methode verändert die Liste selber.

# %%
my_list2 = [0,1,2,3,4]
my_list2.reverse()
my_list2
# Out:
# [4, 3, 2, 1, 0]

# %% [markdown]
# nicht mit explizit angebenen Grenzen lösbar!

# %%
my_list[5:0:-1]
# Out:
# [4, 3, 2, 1]

# %%
my_list[5::-1]
# Out:
# [4, 3, 2, 1, 0]

# %% [markdown]
# #### ein Element in der Liste ersetzen
#
# Listen sind mutable Objekte und können verändert werden.

# %%
my_list = [0,1,2,3,4]

# %%
my_list[0]='Neu'
my_list
# Out:
# ['Neu', 1, 2, 3, 4]

# %% [markdown]
# ### Ersetzen einer Teilliste durch eine andere Liste
#
# [How does assignment work with list slices? ](https://stackoverflow.com/questions/10623302/how-does-assignment-work-with-list-slices)

# %% [markdown]
# Unter Anwendung der Slicing-Notation bekommt man eine Teilliste

# %%
my_list = [0,1,2,3,4]
my_list[1:3]
# Out:
# [1, 2]

# %% [markdown]
# Diese Teilliste in der ursprünglichen Liste kann ich durch eine andere Liste ersetzen:

# %% [markdown]
# Fall 1: Die Teilliste [1,2] in der Liste [0,1,2,3,4] wird durch [10] ersetzt: [0, 10, 3, 4]

# %%
my_list = [0,1,2,3,4]
my_list[1:3] = [10]   # Liste mit nur einem Element
my_list
# Out:
# [0, 10, 3, 4]

# %% [markdown]
# Fall 2: Die Teilliste [1,2] wird durch [10, 11] ersetzt.

# %%
my_list = [0,1,2,3,4]
my_list[1:3] = [10,11] # Liste mit zwei Elementen
my_list
# Out:
# [0, 10, 11, 3, 4]

# %% [markdown]
# Fall 3: Die Teilliste [1,2] wird durch [10, 11, 12] ersetzt.

# %%
my_list = [0,1,2,3,4]
my_list[1:3] = [10,11,12] # Liste mit nur einem Element
my_list
# Out:
# [0, 10, 11, 12, 3, 4]

# %% [markdown]
# weiteres Beispiel: Die Teilliste [3, 4] wird durch ['vorletzter','letzer'] ersetzt.

# %%
my_list = [0,1,2,3,4]
print(my_list[-2:])
my_list[-2:] = ['vorletzter','letzer']
my_list
# Out:
# [3, 4]
# [0, 1, 2, 'vorletzter', 'letzer']

# %% [markdown]
# weiteres Beispiel: Die Teilliste [4] wird durch ['Neu2','Neu3'] ersetzt.

# %%
my_list = [0,1,2,3,4]
print(my_list[-1:])
my_list[-1:] = ['Neu2','Neu3']
my_list
# Out:
# [4]
# [0, 1, 2, 3, 'Neu2', 'Neu3']

# %% [markdown]
# weiteres Beispiel: Die Teilliste [1] wird durch ['Wert1','Wert2'] ersetzt.

# %%
my_list = [0,1,2,3,4]
print(my_list[1:2])
my_list[1:2] = ['Wert1','Wert2']
my_list
# Out:
# [1]
# [0, 'Wert1', 'Wert2', 2, 3, 4]

# %% [markdown]
# #### verschachtelte Listen

# %%
verschachtelt = ['a',[1,2,['A'],3],'b']

# %% [markdown]
# hole `'A'` heraus
#
# <!----
# Lösung
# verschachtelt[1][2][0]
# --->

# %%
verschachtelt[1]
# Out:
# [1, 2, ['A'], 3]

# %%
verschachtelt[1][2]
# Out:
# ['A']

# %%
verschachtelt[1][2][0]
# Out:
# 'A'

# %% [markdown]
# Verschachtelung kann auch mit Tupels erfolgen:

# %%
verschachtelt = ['a',(1,2,('A',),3),]
verschachtelt
# Out:
# ['a', (1, 2, ('A',), 3)]

# %%
verschachtelt[1][2][0]
# Out:
# 'A'

# %% [markdown]
# ## Typumwandlungen
#
# ### String in eine Liste entpacken
#
# im folgenden Kontext ist `*` der _tuple (or iterable) unpacking operator_.
#
# Referenz:
# [unpacking operators](https://geekflare.com/de/python-unpacking-operators)

# %%
a = [*"RealPython"]
print(a)
# Out:
# ['R', 'e', 'a', 'l', 'P', 'y', 't', 'h', 'o', 'n']

# %% [markdown]
# Läuft nicht ohne die eckigen Klammern außenrum.

# %%
a = *"RealPython"
print(a)
# Out:
#   Cell In[81], line 1
#     a = *"RealPython"
#         ^
# SyntaxError: can't use starred expression here

# %% [markdown]
# ### Liste in eine Menge (set) wandeln

# %%
set([1,2,3])
# Out:
# {1, 2, 3}

# %% [markdown]
# ### Menge (set) in eine Liste wandeln

# %%
list({1,2,3})
# Out:
# [1, 2, 3]

# %% [markdown]
# #### Anwendungsbeispiel: Doppelte Werte aus Liste entfernen
#
# Liste in Set wandeln und dies wieder in eine Liste wandeln

# %%
input_liste = [3,2,1,2,2,3,3,1,2,3]
liste_ohne_doppelte_Elemente = list(set(input_liste))
liste_ohne_doppelte_Elemente
# Out:
# [1, 2, 3]
